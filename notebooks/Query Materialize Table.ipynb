# %%
import caveclient

# %%
client = caveclient.CAVEclient('h01_c3_flat')

# %%
datastack = client.info.get_datastack_info('h01_c3_flat')
datastack
# Out:
# {'proofreading_status_table': None,
#  'soma_table': None,
#  'viewer_resolution_z': 33.0,
#  'segmentation_source': 'graphene://https://local.brain-wire-test.org/segmentation/1.0/h01_full0_v2',
#  'proofreading_review_table': None,
#  'viewer_resolution_x': 8.0,
#  'analysis_database': None,
#  'synapse_table': None,
#  'description': 'datastack with the flat c3 segmentation applied',
#  'viewer_resolution_y': 8.0,
#  'viewer_site': 'https://h01-dot-neuroglancer-demo.appspot.com/',
#  'local_server': 'https://local.brain-wire-test.org',
#  'aligned_volume': {'id': 1,
#   'image_source': 'precomputed://gs://h01-release/data/20210601/4nm_raw',
#   'name': 'h01',
#   'description': 'aligned volume image stack of H01'},
#  'cell_identification_table': None}

# %%
client.materialize.get_versions()
# Out:
# [64, 47]

# %%
client.materialize.version
# Out:
# 64

# %%
client.materialize.query_table(table="test_table", 
                               datastack_name="h01_c3_flat", 
                               limit=10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 client.materialize.query_table(table="test_table",
#       2                                datastack_name="h01_c3_flat",
#       3                                limit=10)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/materializationengine.py:653, in MaterializatonClientV2.query_table(self, table, filter_in_dict, filter_out_dict, filter_equal_dict, filter_spatial_dict, select_columns, offset, limit, datastack_name, return_df, split_positions, materialization_version, timestamp, metadata, merge_reference, desired_resolution, get_counts)
#     650 if datastack_name is None:
#     651     datastack_name = self.datastack_name
# --> 653 tables, suffix_map = self._resolve_merge_reference(
#     654     merge_reference, table, datastack_name, materialization_version
#     655 )
#     657 url, data, query_args, encoding = self._format_query_components(
#     658     datastack_name,
#     659     materialization_version,
#    (...)
#     671     desired_resolution,
#     672 )
#     673 if get_counts:
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/materializationengine.py:532, in MaterializatonClientV2._resolve_merge_reference(self, merge_reference, table, datastack_name, materialization_version)
#     528 def _resolve_merge_reference(
#     529     self, merge_reference, table, datastack_name, materialization_version
#     530 ):
#     531     if merge_reference:
# --> 532         md = self.get_table_metadata(
#     533             table_name=table,
#     534             datastack_name=datastack_name,
#     535             version=materialization_version,
#     536             log_warning=False,
#     537         )
#     538         if md["reference_table"] is None:
#     539             target_table = None
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/cachetools/__init__.py:737, in cached.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     735 except KeyError:
#     736     pass  # key not found
# --> 737 v = func(*args, **kwargs)
#     738 try:
#     739     cache[k] = v
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/materializationengine.py:445, in MaterializatonClientV2.get_table_metadata(self, table_name, datastack_name, version, log_warning)
#     442 url = self._endpoints["metadata"].format_map(endpoint_mapping)
#     444 response = self.session.get(url)
# --> 445 metadata_d = handle_response(response, log_warning=log_warning)
#     446 vx = metadata_d.pop("voxel_resolution_x", None)
#     447 vy = metadata_d.pop("voxel_resolution_y", None)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/base.py:81, in handle_response(response, as_json, log_warning)
#      79 def handle_response(response, as_json=True, log_warning=True):
#      80     """Deal with potential errors in endpoint response and return json for default case"""
# ---> 81     _raise_for_status(response, log_warning=log_warning)
#      82     _check_authorization_redirect(response)
#      83     if as_json:
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/base.py:72, in _raise_for_status(r, log_warning)
#      64     http_error_msg = "%s Server Error: %s for url: %s content:%s" % (
#      65         r.status_code,
#      66         reason,
#      67         r.url,
#      68         r.content,
#      69     )
#      71 if http_error_msg:
# ---> 72     raise requests.HTTPError(http_error_msg, response=r)
#      73 if log_warning:
#      74     warning = r.headers.get("Warning")
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: https://local.brain-wire-test.org/materialize/api/v3/datastack/h01_c3_flat/version/64/table/test_table/metadata content:b'{"message": "Internal Server Error"}\n'

# %%
client.materialize.query_table("test_table", 
                               limit=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 client.materialize.query_table("test_table",
#       2                                limit=10)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/materializationengine.py:653, in MaterializatonClientV2.query_table(self, table, filter_in_dict, filter_out_dict, filter_equal_dict, filter_spatial_dict, select_columns, offset, limit, datastack_name, return_df, split_positions, materialization_version, timestamp, metadata, merge_reference, desired_resolution, get_counts)
#     650 if datastack_name is None:
#     651     datastack_name = self.datastack_name
# --> 653 tables, suffix_map = self._resolve_merge_reference(
#     654     merge_reference, table, datastack_name, materialization_version
#     655 )
#     657 url, data, query_args, encoding = self._format_query_components(
#     658     datastack_name,
#     659     materialization_version,
#    (...)
#     671     desired_resolution,
#     672 )
#     673 if get_counts:
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/materializationengine.py:532, in MaterializatonClientV2._resolve_merge_reference(self, merge_reference, table, datastack_name, materialization_version)
#     528 def _resolve_merge_reference(
#     529     self, merge_reference, table, datastack_name, materialization_version
#     530 ):
#     531     if merge_reference:
# --> 532         md = self.get_table_metadata(
#     533             table_name=table,
#     534             datastack_name=datastack_name,
#     535             version=materialization_version,
#     536             log_warning=False,
#     537         )
#     538         if md["reference_table"] is None:
#     539             target_table = None
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/cachetools/__init__.py:737, in cached.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     735 except KeyError:
#     736     pass  # key not found
# --> 737 v = func(*args, **kwargs)
#     738 try:
#     739     cache[k] = v
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/caveclient/materializationengine.py:444, in MaterializatonClientV2.get_table_metadata(self, table_name, datastack_name, version, log_warning)
#     440 endpoint_mapping["version"] = version
#     442 url = self._endpoints["metadata"].format_map(endpoint_mapping)
# --> 444 response = self.session.get(url)
#     445 metadata_d = handle_response(response, log_warning=log_warning)
#     446 vx = metadata_d.pop("voxel_resolution_x", None)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/urllib3/connectionpool.py:826, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     821 if not conn:
#     822     # Try again
#     823     log.warning(
#     824         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     825     )
# --> 826     return self.urlopen(
#     827         method,
#     828         url,
#     829         body,
#     830         headers,
#     831         retries,
#     832         redirect,
#     833         assert_same_host,
#     834         timeout=timeout,
#     835         pool_timeout=pool_timeout,
#     836         release_conn=release_conn,
#     837         chunked=chunked,
#     838         body_pos=body_pos,
#     839         **response_kw
#     840     )
#     842 # Handle redirect?
#     843 redirect_location = redirect and response.get_redirect_location()
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/ng/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

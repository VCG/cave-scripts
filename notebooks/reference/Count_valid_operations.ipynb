# %%
from pychunkedgraph.graph import ChunkedGraph, attributes
import numpy as np
import collections
import matplotlib.pyplot as plt
from collections import defaultdict
from datetime import datetime
import matplotlib.dates as mdates
import numpy as np
from caveclient import CAVEclient, auth
from caveclient import chunkedgraph as cg

# %%
dataset = "fish_v241003_test"
cg = ChunkedGraph(graph_id=dataset)

# %% [markdown]
# ### Get all operations

# %%
max_op_id = cg.client.get_max_operation_id()
max_op_id
# Out:
# 4983

# %%
url = "https://pcgv3local.brain-wire-test.org"
global_url = "https://global.brain-wire-test.org/"
datastack = "fish1_full"
dataset = "fish_v241003"
resolution = [16, 16, 30]

# %%
client = CAVEclient(datastack_name=datastack, server_address=global_url)
cggraph = cg.ChunkedGraphClient(server_address=url, table_name=dataset, auth_client=auth.AuthClient(token=client.auth.token))
cv = client.info.segmentation_cloudvolume()

# %%
cggraph.get_operation_details(list(range(22530050-100, 22530050)))
# Out:
# {'22529953': {'added_edges': [[83673249472315839, 83532649557131295]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:10.173000+00:00',
#   'roots': [864691128661129585],
#   'sink_coords': [[41844, 18457, 4608]],
#   'source_coords': [[42249, 18027, 4392]],
#   'timestamp': '2025-01-07 14:34:10.173000+00:00',
#   'user': '31'},
#  '22529958': {'added_edges': [[80718447331246344, 80577366648160613]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:18.559000+00:00',
#   'roots': [864691128667069921],
#   'sink_coords': [[31206, 19223, 1157]],
#   'source_coords': [[31743, 20695, 423]],
#   'timestamp': '2025-01-07 14:34:18.559000+00:00',
#   'user': '31'},
#  '22529963': {'added_edges': [[79802899823067255, 79803106317043209]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:24.333000+00:00',
#   'roots': [864691128658209282],
#   'sink_coords': [[28372, 18501, 5090]],
#   'source_coords': [[28226, 17912, 4356]],
#   'timestamp': '2025-01-07 14:34:24.333000+00:00',
#   'user': '31'},
#  '22529966': {'added_edges': [[79310318546715057, 79310249961457012]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:26.501000+00:00',
#   'roots': [864691128693352277],
#   'sink_coords': [[26534, 17575, 4586]],
#   'source_coords': [[26424, 17672, 4336]],
#   'timestamp': '2025-01-07 14:34:26.501000+00:00',
#   'user': '31'},
#  '22529968': {'added_edges': [[79662162267603037, 79662162468929642]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:28.088000+00:00',
#   'roots': [864691128675169623],
#   'sink_coords': [[27709, 17842, 4614]],
#   'source_coords': [[27775, 17674, 4225]],
#   'timestamp': '2025-01-07 14:34:28.088000+00:00',
#   'user': '31'},
#  '22529970': {'added_edges': [[82125137100406947, 82407505832969776]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:29.853000+00:00',
#   'roots': [864691128682960631],
#   'sink_coords': [[37766, 21374, 5192]],
#   'source_coords': [[36608, 17930, 4355]],
#   'timestamp': '2025-01-07 14:34:29.853000+00:00',
#   'user': '31'},
#  '22529971': {'added_edges': [[87121180498067832, 87120905553055110]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:30.088000+00:00',
#   'roots': [864691128676755487],
#   'sink_coords': [[55029, 16491, 4343]],
#   'source_coords': [[54827, 17644, 4368]],
#   'timestamp': '2025-01-07 14:34:30.088000+00:00',
#   'user': '31'},
#  '22529973': {'added_edges': [[75511093086126233, 75722268172353666]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:31.299000+00:00',
#   'roots': [864691128671521717],
#   'sink_coords': [[13492, 20689, 3608]],
#   'source_coords': [[12587, 20273, 3404]],
#   'timestamp': '2025-01-07 14:34:31.299000+00:00',
#   'user': '31'},
#  '22529975': {'added_edges': [[81843593404219577, 81843593538437309]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:32.357000+00:00',
#   'roots': [864691128701433484],
#   'sink_coords': [[35730, 17774, 4631]],
#   'source_coords': [[35769, 17870, 4400]],
#   'timestamp': '2025-01-07 14:34:32.357000+00:00',
#   'user': '31'},
#  '22529977': {'added_edges': [[80999168474087513, 80999031303570513]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:34.694000+00:00',
#   'roots': [864691128666803038],
#   'sink_coords': [[32554, 17237, 4976]],
#   'source_coords': [[32672, 17669, 4364]],
#   'timestamp': '2025-01-07 14:34:34.694000+00:00',
#   'user': '31'},
#  '22529978': {'added_edges': [[85573136644309689, 85432399290172130]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:34.923000+00:00',
#   'roots': [864691128671521461],
#   'sink_coords': [[48886, 17724, 4293]],
#   'source_coords': [[49240, 17784, 4062]],
#   'timestamp': '2025-01-07 14:34:34.923000+00:00',
#   'user': '31'},
#  '22529979': {'added_edges': [[83673249472315839, 83532512185287678]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:35.967000+00:00',
#   'roots': [864691128662452192],
#   'sink_coords': [[41936, 18066, 4792]],
#   'source_coords': [[42249, 18027, 4392]],
#   'timestamp': '2025-01-07 14:34:35.967000+00:00',
#   'user': '31'},
#  '22529987': {'added_edges': [[80788817686036697, 80648217837963170]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:43.420000+00:00',
#   'roots': [864691128699721571],
#   'sink_coords': [[31347, 21131, 3961]],
#   'source_coords': [[31774, 20654, 3482]],
#   'timestamp': '2025-01-07 14:34:43.420000+00:00',
#   'user': '31'},
#  '22529990': {'added_edges': [[84658343171326053, 84658136945787244]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:45.011000+00:00',
#   'roots': [864691128690769578],
#   'sink_coords': [[45931, 16934, 4281]],
#   'source_coords': [[45883, 17664, 4364]],
#   'timestamp': '2025-01-07 14:34:45.011000+00:00',
#   'user': '31'},
#  '22529997': {'added_edges': [[80788817686036697, 80507617654342443]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:49.730000+00:00',
#   'roots': [864691128661129841],
#   'sink_coords': [[30922, 21527, 3624]],
#   'source_coords': [[31774, 20654, 3482]],
#   'timestamp': '2025-01-07 14:34:49.730000+00:00',
#   'user': '31'},
#  '22530004': {'added_edges': [[83673249472315839, 83532512185286907]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:53.637000+00:00',
#   'roots': [864691128698932294],
#   'sink_coords': [[41958, 18014, 4741]],
#   'source_coords': [[42249, 18027, 4392]],
#   'timestamp': '2025-01-07 14:34:53.637000+00:00',
#   'user': '31'},
#  '22530007': {'added_edges': [[75511093086126233, 75933374337777753]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:56.686000+00:00',
#   'roots': [864691128668598355],
#   'sink_coords': [[14115, 20547, 3475]],
#   'source_coords': [[12587, 20273, 3404]],
#   'timestamp': '2025-01-07 14:34:56.686000+00:00',
#   'user': '31'},
#  '22530009': {'added_edges': [[79310318546715057, 79310250028565155]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:57.452000+00:00',
#   'roots': [864691128661130097],
#   'sink_coords': [[26481, 17498, 4644]],
#   'source_coords': [[26424, 17672, 4336]],
#   'timestamp': '2025-01-07 14:34:57.452000+00:00',
#   'user': '31'},
#  '22530010': {'added_edges': [[84658343171326053, 84658136945787027]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:34:57.882000+00:00',
#   'roots': [864691128677770860],
#   'sink_coords': [[45844, 17017, 4239]],
#   'source_coords': [[45883, 17664, 4364]],
#   'timestamp': '2025-01-07 14:34:57.882000+00:00',
#   'user': '31'},
#  '22530019': {'added_edges': [[87121180498067832, 87191343016709629]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:08.568000+00:00',
#   'roots': [864691128672012742],
#   'sink_coords': [[55231, 16652, 4345]],
#   'source_coords': [[54827, 17644, 4368]],
#   'timestamp': '2025-01-07 14:35:08.568000+00:00',
#   'user': '31'},
#  '22530022': {'added_edges': [[80155567707914568, 80155499189764337]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:10.379000+00:00',
#   'roots': [864691128668646762],
#   'sink_coords': [[29598, 20671, 3856]],
#   'source_coords': [[29680, 20736, 3520]],
#   'timestamp': '2025-01-07 14:35:10.379000+00:00',
#   'user': '31'},
#  '22530023': {'added_edges': [[80859255149691274, 80718655234507200]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:11.316000+00:00',
#   'roots': [864691128682960887],
#   'sink_coords': [[31706, 21313, 3739]],
#   'source_coords': [[32107, 20950, 3520]],
#   'timestamp': '2025-01-07 14:35:11.316000+00:00',
#   'user': '31'},
#  '22530024': {'added_edges': [[81562118360400141, 81491612445704420]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:11.524000+00:00',
#   'roots': [864691128677093523],
#   'sink_coords': [[34552, 17217, 4763]],
#   'source_coords': [[34588, 17758, 4274]],
#   'timestamp': '2025-01-07 14:35:11.524000+00:00',
#   'user': '31'},
#  '22530028': {'added_edges': [[83673249472315839, 83532512185287319]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:15.169000+00:00',
#   'roots': [864691128667913292],
#   'sink_coords': [[41944, 18061, 4769]],
#   'source_coords': [[42249, 18027, 4392]],
#   'timestamp': '2025-01-07 14:35:15.169000+00:00',
#   'user': '31'},
#  '22530030': {'added_edges': [[79310318546715057, 79239881284386886]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:19.795000+00:00',
#   'roots': [864691128675169879],
#   'sink_coords': [[26319, 17643, 4609]],
#   'source_coords': [[26424, 17672, 4336]],
#   'timestamp': '2025-01-07 14:35:19.795000+00:00',
#   'user': '31'},
#  '22530031': {'added_edges': [[79100036545250341, 78959849349580460]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:19.972000+00:00',
#   'roots': [864691128698984576],
#   'sink_coords': [[25250, 22831, 4595]],
#   'source_coords': [[25793, 20875, 3527]],
#   'timestamp': '2025-01-07 14:35:19.972000+00:00',
#   'user': '31'},
#  '22530032': {'added_edges': [[80718447331246344, 80506998105310455]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:23.384000+00:00',
#   'roots': [864691128666275537],
#   'sink_coords': [[30723, 19439, 1635]],
#   'source_coords': [[31743, 20695, 423]],
#   'timestamp': '2025-01-07 14:35:23.384000+00:00',
#   'user': '31'},
#  '22530034': {'added_edges': [[79662162267603037, 79662025029976446]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:24.276000+00:00',
#   'roots': [864691128674829836],
#   'sink_coords': [[27888, 17352, 4667]],
#   'source_coords': [[27775, 17674, 4225]],
#   'timestamp': '2025-01-07 14:35:24.276000+00:00',
#   'user': '31'},
#  '22530036': {'added_edges': [[75511093086126233, 75863005526491674]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:25.962000+00:00',
#   'roots': [864691128699721827],
#   'sink_coords': [[14040, 20499, 3444]],
#   'source_coords': [[12587, 20273, 3404]],
#   'timestamp': '2025-01-07 14:35:25.962000+00:00',
#   'user': '31'},
#  '22530043': {'added_edges': [[84658343171326053, 84728712049721686]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:32.199000+00:00',
#   'roots': [864691128648093948],
#   'sink_coords': [[46166, 17903, 4642]],
#   'source_coords': [[45883, 17664, 4364]],
#   'timestamp': '2025-01-07 14:35:32.199000+00:00',
#   'user': '31'},
#  '22530044': {'added_edges': [[79662162267603037, 79591793724752885]],
#   'operation_exception': '',
#   'operation_status': 0,
#   'operation_ts': '2025-01-07 14:35:32.720000+00:00',
#   'roots': [864691128663746388],
#   'sink_coords': [[27509, 17896, 4703]],
#   'source_coords': [[27775, 17674, 4225]],
#   'timestamp': '2025-01-07 14:35:32.720000+00:00',
#   'user': '31'}}

# %%
max_op_id = cg.client.get_max_operation_id()
# max_op_id = 5000000
log_rows = {}
num_sections = max(1, max_op_id // 100000)
for id_batch in np.array_split(np.arange(0, max_op_id), num_sections):
    # %time log_rows.update(cg.client.read_log_entries(operation_ids=id_batch))
# Out:
# CPU times: user 796 ms, sys: 22.2 ms, total: 818 ms
# Wall time: 1.27 s

# %%
log_data = collections.defaultdict(list)

failed_operations = 0
for operation_id, log_row in log_rows.items():
    if log_row.get(attributes.OperationLogs.Status, 0) != 0:
        # continue
        failed_operations += 1
        
    # log_data["date"].append(log_row["timestamp"])
    # log_data["timestamp"].append(log_row["timestamp"].timestamp())
    # log_data["user_id"].append(log_row[attributes.OperationLogs.UserID])
    
    # if log_row[attributes.OperationLogs.SinkCoordinate][0][0] > 1e9:
    #     sinks = np.frombuffer(log_row[attributes.OperationLogs.SinkCoordinate]).reshape(-1, 3)
    #     sources = np.frombuffer(log_row[attributes.OperationLogs.SourceCoordinate]).reshape(-1, 3)
    # else:
    #     sinks = log_row[attributes.OperationLogs.SinkCoordinate]
    #     sources = log_row[attributes.OperationLogs.SourceCoordinate]
    # mean_coord = (np.mean(sinks, axis=0) + np.mean(sources, axis=0)) / 2
    # log_data["coord_x"].append(mean_coord[0])
    # log_data["coord_y"].append(mean_coord[1])
    # log_data["coord_z"].append(mean_coord[2])
    # log_data["operation_id"].append(operation_id)

# %%
failed_operations
# Out:
# 2

# %% [markdown]
# ### Plot results

# %%
# Sort the dates to ensure the cumulative sum is calculated in order
# dates = sorted(log_data['date'])
dates = [d.replace(tzinfo=None) for d in sorted(log_data['date'])]

# Initialize cumulative count
cumulative_counts = []
cumulative_sum = 0

# Calculate cumulative sum of edits over time
for _ in dates:
    cumulative_sum += 1
    cumulative_counts.append(cumulative_sum)

def add_months(source_date, months):
    # Calculate the new month and year considering year overflow
    month = source_date.month - 1 + months
    year = source_date.year + month // 12
    month = month % 12 + 1
    day = min(source_date.day, [31, 29 if (year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)) else 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31][month - 1])
    return datetime(year, month, day, source_date.hour, source_date.minute, source_date.second, source_date.microsecond)

range_dates = []
range_counts = []

next_marker_date = dates[0]  # Start from the first date
print(dates, next_marker_date)
for i, date in enumerate(dates):
    if date >= next_marker_date:  # If current date is on or after the next marker date
        range_dates.append(date)
        range_counts.append(cumulative_counts[i])
        next_marker_date = add_months(next_marker_date, 3)

# Plot the line for all data
plt.figure(figsize=(10, 6))
plt.plot(dates, cumulative_counts, linestyle='-', color='b')

# Add circle markers at exact intervals
plt.plot(range_dates, range_counts, marker='o', linestyle='None', color='r')

# Formatting the date on the x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format the x-axis labels as Year-Month
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # Set the locator to intervals

plt.gcf().autofmt_xdate()  # Auto format the x-axis for better readability
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.ylabel('Cumulative Edit Count')
plt.title('{}: Cumulative Number of Edits Over Time'.format(dataset))
# plt.grid(True)
plt.legend()
plt.show()
# Out:
# [datetime.datetime(2022, 10, 1, 17, 23, 11, 400000), datetime.datetime(2022, 10, 1, 17, 50, 59, 205000), datetime.datetime(2022, 10, 1, 17, 51, 32, 424000), datetime.datetime(2022, 10, 1, 17, 51, 49, 209000), datetime.datetime(2022, 10, 1, 17, 52, 2, 206000), datetime.datetime(2022, 10, 1, 20, 28, 35, 567000), datetime.datetime(2022, 10, 1, 20, 28, 50, 647000), datetime.datetime(2022, 10, 1, 20, 29, 23, 544000), datetime.datetime(2022, 10, 1, 20, 31, 6, 840000), datetime.datetime(2022, 10, 2, 17, 56, 8, 148000), datetime.datetime(2022, 10, 2, 17, 56, 32, 728000), datetime.datetime(2022, 10, 2, 17, 57, 37, 372000), datetime.datetime(2022, 10, 2, 17, 58, 22, 985000), datetime.datetime(2022, 10, 2, 17, 58, 35, 135000), datetime.datetime(2022, 10, 2, 17, 58, 43, 278000), datetime.datetime(2022, 10, 2, 17, 59, 24, 771000), datetime.datetime(2022, 10, 2, 17, 59, 39, 769000), datetime.datetime(2022, 10, 2, 17, 59, 58, 949000), datetime.datetime(2022, 10, 2, 18, 0, 48, 476000), datetime.datetime(2022, 10, 2, 18, 1, 4, 225000), datetime.datetime(2022, 10, 2, 18, 1, 28, 708000), datetime.datetime(2022, 10, 2, 18, 9, 30, 401000), datetime.datetime(2022, 10, 2, 18, 12, 34, 844000), datetime.datetime(2022, 10, 2, 18, 23, 50, 41000), datetime.datetime(2022, 10, 2, 18, 25, 9, 952000), datetime.datetime(2022, 10, 2, 18, 26, 48, 386000), datetime.datetime(2022, 10, 2, 18, 38, 19, 130000), datetime.datetime(2022, 10, 2, 18, 40, 28, 718000), datetime.datetime(2022, 10, 2, 18, 44, 41, 658000), datetime.datetime(2022, 10, 2, 18, 45, 5, 378000), datetime.datetime(2022, 10, 3, 17, 17, 32, 987000), datetime.datetime(2022, 10, 3, 17, 17, 47, 178000), datetime.datetime(2022, 10, 3, 17, 18, 4, 301000), datetime.datetime(2022, 10, 3, 17, 18, 27, 460000), datetime.datetime(2022, 10, 3, 20, 6, 45, 378000), datetime.datetime(2022, 10, 3, 20, 15, 51, 615000), datetime.datetime(2022, 10, 3, 20, 31, 0, 427000), datetime.datetime(2022, 10, 3, 20, 35, 53, 837000), datetime.datetime(2022, 10, 3, 20, 40, 9, 600000), datetime.datetime(2022, 10, 3, 20, 41, 23, 357000), datetime.datetime(2022, 10, 3, 20, 42, 57, 635000), datetime.datetime(2022, 10, 3, 20, 43, 19, 450000), datetime.datetime(2022, 10, 3, 20, 45, 12, 946000), datetime.datetime(2022, 10, 3, 20, 45, 32, 860000), datetime.datetime(2022, 10, 3, 20, 46, 29, 988000), datetime.datetime(2022, 10, 3, 20, 47, 9, 929000), datetime.datetime(2022, 10, 3, 20, 50, 44, 614000), datetime.datetime(2022, 10, 4, 1, 46, 44, 237000), datetime.datetime(2022, 10, 4, 1, 47, 40, 634000), datetime.datetime(2022, 10, 4, 1, 48, 3, 921000), datetime.datetime(2022, 10, 4, 1, 49, 31, 286000), datetime.datetime(2022, 10, 4, 1, 49, 44, 341000), datetime.datetime(2022, 10, 4, 1, 50, 6, 946000), datetime.datetime(2022, 10, 4, 1, 50, 32, 479000), datetime.datetime(2022, 10, 4, 1, 50, 46, 504000), datetime.datetime(2022, 10, 4, 1, 51, 2, 158000), datetime.datetime(2022, 10, 4, 1, 59, 36, 801000), datetime.datetime(2022, 10, 4, 2, 3, 57, 103000), datetime.datetime(2022, 10, 4, 2, 31, 24, 528000), datetime.datetime(2022, 10, 4, 2, 32, 57, 581000), datetime.datetime(2022, 10, 4, 14, 31, 49, 715000), datetime.datetime(2022, 10, 4, 15, 5, 59, 812000), datetime.datetime(2022, 10, 4, 15, 8, 46, 181000), datetime.datetime(2022, 10, 4, 15, 14, 7, 18000), datetime.datetime(2022, 10, 4, 15, 41, 12, 297000), datetime.datetime(2022, 10, 4, 15, 42, 30, 924000), datetime.datetime(2022, 10, 4, 15, 50, 30, 999000), datetime.datetime(2022, 10, 4, 15, 51, 32, 394000), datetime.datetime(2022, 10, 4, 15, 53, 45, 501000), datetime.datetime(2022, 10, 4, 15, 54, 52, 727000), datetime.datetime(2022, 10, 4, 15, 56, 12, 650000), datetime.datetime(2022, 10, 4, 15, 57, 39, 895000), datetime.datetime(2022, 10, 4, 15, 59, 5, 647000), datetime.datetime(2022, 10, 4, 16, 0, 9, 600000), datetime.datetime(2022, 10, 4, 16, 35, 15, 579000), datetime.datetime(2022, 10, 4, 16, 54, 46, 851000), datetime.datetime(2022, 10, 4, 16, 55, 3, 701000), datetime.datetime(2022, 10, 4, 16, 5 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 31
#      29         range_dates.append(date)
#      30         range_counts.append(cumulative_counts[i])
# ---> 31         next_marker_date = add_months(next_marker_date, 3)
#      33 # Plot the line for all data
#      34 plt.figure(figsize=(10, 6))
#
# Cell In[8], line 20, in add_months(source_date, months)
#      18 month = month % 12 + 1
#      19 day = min(source_date.day, [31, 29 if (year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)) else 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31][month - 1])
# ---> 20 return datetime(year, month, day, source_date.hour, source_date.minute, source_date.second, source_date.microsecond)
#
# NameError: name 'datetime' is not defined

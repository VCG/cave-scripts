# %%
# !pip install caveclient
# Out:
# Requirement already satisfied: caveclient in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (5.4.0)
# Requirement already satisfied: urllib3 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (1.26.9)
# Requirement already satisfied: requests in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (2.27.1)
# Requirement already satisfied: networkx in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (2.7.1)
# Requirement already satisfied: jsonschema in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (4.4.0)
# Requirement already satisfied: ipython in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (8.2.0)
# Requirement already satisfied: pandas in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (1.4.2)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (4.2.2)
# Requirement already satisfied: numpy in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (1.21.5)
# Requirement already satisfied: pyarrow>=3 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages/pyarrow-7.0.0-py3.9-macosx-10.9-x86_64.egg (from caveclient) (7.0.0)
# Requirement already satisfied: attrs>=21.3.0 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from caveclient) (21.4.0)
# Requirement already satisfied: pexpect>4.3 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (0.1.2)
# Requirement already satisfied: backcall in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (0.2.0)
# Requirement already satisfied: decorator in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (2.11.2)
# Requirement already satisfied: stack-data in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (5.1.1)
# Requirement already satisfied: appnope in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (0.1.2)
# Requirement already satisfied: pickleshare in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from ipython->caveclient) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->caveclient) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->caveclient) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->caveclient) (0.2.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from jsonschema->caveclient) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from pandas->caveclient) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from pandas->caveclient) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->caveclient) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from requests->caveclient) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from requests->caveclient) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from requests->caveclient) (3.3)
# Requirement already satisfied: asttokens in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->caveclient) (2.0.5)
# Requirement already satisfied: executing in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->caveclient) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/jinhan/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->caveclient) (0.2.2)

# %%
from caveclient import CAVEclient
import numpy as np
import pandas as pd

# %%
annoDf = pd.read_csv('../data/dbcells-dump.csv')

# %%
annoDf.head()
# Out:
#    dbcellid  x  y  z  goog14r0seg1_baseid  google_aggloid dbcelltype  \
# 0     49363  0  0  0                    0               0   UNKNOWN0
# 1     49364  0  0  0                    0               0   UNKNOWN0
# 2     49365  0  0  0                    0               0   UNKNOWN0
# 3     49366  0  0  0                    0               0   UNKNOWN0
# 4     49367  0  0  0                    0               0   UNKNOWN0
#
#    dbsubcelltype  dbsubcelltype2  dbsubcelltype3  nrvoxels  circulardepth
# 0              0               0               0         0            780
# 1              0               0               0         0            780
# 2              0               0               0         0            780
# 3              0               0               0         0            780
# 4              0               0               0         0            780

# %%
annoDf.shape
# Out:
# (49377, 12)

# %%
columns = ["type", "dbcellid", "x", "y", "z", "xmin", "ymin", "zmin", "xmax", "ymax", "zmax", "volume", "dbcelltype_code"]
# 1: 1 for neuron/glia cell body, 2 for blood vessel nucleus
# 2: ID in the VAST segmentation file (for neurons/glia this should be
# consistent with the 'dbid' value in other tables)
# 3-5: X,Y,Z anchor point within cell body or nucleus, in pixels at 8x8x33 nm
# 6-11: Xmin,Ymin,Zmin,Xmax,Ymax,Zmax of bounding box of cell body or
# nucleus, in pixels at 8x8x33 nm
# 12: volume estimate of cell body or nucleus in cubic micrometers, at
# _very low resolution_ (mip6 every 128th section for neurons/glia, mip7
# every 16th section for bv nuclei, manually painted)
# 13: cell type code (manually classified):
cbDf = pd.read_csv('../data/h01_cell_body_nucleus_matrix_may16_2023.csv', names=columns)

# %%
cbDf.head()
# Out:
#    type  dbcellid       x       y     z    xmin    ymin  zmin    xmax    ymax  \
# 0     1         1  259891  165404  1408  258240  163392   896  262335  167167
# 1     1         2  261308  171181  1024  259968  169856   512  262463  172543
# 2     1         3  256788  171573  1408  255552  170688  1152  258367  173119
# 3     1         4  254675  164220  1280  253376  163072  1152  255679  165375
# 4     1         5  258308  160604  1536  257472  159744  1408  259327  161791
#
#    zmax       volume  dbcelltype_code
# 0  1551  8825.151160                1
# 1  1295  5967.219524                1
# 2  1679  3984.051929                1
# 3  1679  3402.721395                1
# 4  1807  2142.618255                1

# %%
cbDf.tail()
# Out:
#        type  dbcellid       x       y     z    xmin    ymin  zmin    xmax  \
# 57307     2      8209  154579  154504  4224  154240  154048  4128  154879
# 57308     2      8210  277041  149728   992  276800  148352   864  277759
# 57309     2      8211  276946  148654   992  276864  147840   704  277631
# 57310     2      8212  273233  181627  5280  273152  181248  5248  273727
# 57311     2      8213  448208  165140  1600  448000  164928  1600  448639
#
#          ymax  zmax     volume  dbcelltype_code
# 57307  154943  4335  80.832627               11
# 57308  149823  1007  90.798293               15
# 57309  148799  1007  81.939923               15
# 57310  182463  5295  40.969961               12
# 57311  165631  1839  84.154515               11

# %%
cbDf.shape
# Out:
# (57312, 13)

# %%
cbDf[cbDf.type==1].shape
# Out:
# (49108, 13)

# %%
cbDf[cbDf.type==2].shape
# Out:
# (8204, 13)

# %% [markdown]
# ## Check data join

# %%
df = pd.merge(annoDf, cbDf, on=['dbcellid', 'x', 'y', 'z'], how="inner")
df
# Out:
#        dbcellid       x       y     z  goog14r0seg1_baseid  google_aggloid  \
# 0         36167  334046  102775     0                    0               0
# 1          4702  173580  201477     0           5579334176      5579334176
# 2          7469  248108  170760     0           4577384303      4577384303
# 3         36165  332066   99901     0           1872623538      2221907190
# 4         43352  320388   56535     0            329473037       518394751
# ...         ...     ...     ...   ...                  ...             ...
# 49066     17501  235985  191385  1921          22977375653     40591466610
# 49067     48840  205304  143482  5249          65497765963     91991908616
# 49068     38326  319163  249034   131           6035046399      7054269922
# 49069     21002  267462  136502  2691          38772897807     47623659810
# 49070     27863  391015   90796  3303          37408801249     54950076961
#
#                dbcelltype  dbsubcelltype  dbsubcelltype2  dbsubcelltype3  ...  \
# 0               PYRAMIDAL              0               0               0  ...
# 1      UNCLASSIFIEDNEURON              0               0               0  ...
# 2                UNKNOWN2              0               0               0  ...
# 3      UNCLASSIFIEDNEURON             16               0               0  ...
# 4               PYRAMIDAL              0               0               0  ...
# ...                   ...            ...             ...             ...  ...
# 49066           ASTROCYTE              0               0               0  ...
# 49067           ASTROCYTE              0               0               0  ...
# 49068  UNCLASSIFIEDNEURON             16               0               0  ...
# 49069              MG_OPC              0               0               0  ...
# 49070         INTERNEURON              0               0               0  ...
#
#        circulardepth  type    xmin    ymin  zmin    xmax    ymax  zmax  \
# 0                918     1  332800  101568     0  335167  104127    15
# 1               2350     1  172352  200192     0  175103  203199   271
# 2               1789     1  246656  169856     0  249407  171967    15
# 3                914     1  331328   99136     0  332863  101311   143
# 4                721     1  319744   54976     0  321407   57535   143
# ...              ...   ...     ...     ...   ...     ...     ...   ...
# 49066           1975     1  235264  190592  1792  236671  192511  2063
# 49067           1821     1  204800  142656  5120  205951  144319  5263
# 49068           1644     1  317632  248128   128  320959  250111   399
# 49069           1483     1  267136  135872  2688  267711  137215  2831
# 49070            512     1  390528   90176  3200  391807   91903  3471
#
#             volume  dbcelltype_code
# 0      1118.369219                1
# 1      3388.326543               10
# 2      1125.012996               10
# 3      1151.588106                3
# 4      1141.622440                1
# ...            ...              ...
# 49066  1081.828442                4
# 49067   524.858425                4
# 49068  2183.588217               10
# 49069   195.991437                6
# 49070   907.982930                2
#
# [49071 rows x 21 columns]

# %%
df = pd.merge(annoDf, cbDf[cbDf.type==2], on=['dbcellid', 'x', 'y', 'z'], how="inner")
df
# Out:
# Empty DataFrame
# Columns: [dbcellid, x, y, z, goog14r0seg1_baseid, google_aggloid, dbcelltype, dbsubcelltype, dbsubcelltype2, dbsubcelltype3, nrvoxels, circulardepth, type, xmin, ymin, zmin, xmax, ymax, zmax, volume, dbcelltype_code]
# Index: []
#
# [0 rows x 21 columns]

# %%
excluded_df = annoDf[-annoDf['dbcellid'].isin(df['dbcellid'])]

# %%
excluded_df.shape
# Out:
# (306, 12)

# %%
excluded_df.iloc[100:120]
# Out:
#        dbcellid       x       y     z  goog14r0seg1_baseid  google_aggloid  \
# 16849     48982   77163  250952  3840          77954476538     77954491334
# 16850     49038   92786  252781  3840          78013231072     78013231072
# 17020     47347  161402  214437  3840          76734504308     76734504308
# 17483     49052  355447   74492  3840          72053556287     72053556287
# 18022     49167  374161  165047  4096          75096667522     75096667522
# 18033     46777   95492  254992  4096          51504638581     69264446136
# 18139     49040  250657  260533  4096          78193204226     78251447758
# 18377     47373   96756  255000  4096          78086134272     78086149343
# 18379     49115  104369  194954  4096          76048377238     76048377238
# 18401     47822   94231  253829  4096          78013309131     78013309131
# 18580     49116  115876  284853  4096          60821914391     79091254322
# 18657     46795  417266  223781  4096          59318038461     77048777611
# 18688     47645  214820  215226  4096          67740070238     85616190340
# 19364     46389   98598  253510  4352          86878770068     86878770068
# 19497     47756  296902  263821  4352          87220214396     87220214396
# 19498     47788  230733  259459  4352          87072436647     87072436648
# 19621     48924   77199  227927  4352          86019179250     86019180110
# 19672     47613   99217  257365  4352          86995240835     86995240835
# 19673     47886   89892  229956  4352          86092389583     86092389583
# 19696     47087  326710  241792  4352          86493346800     86493346800
#
#             dbcelltype  dbsubcelltype  dbsubcelltype2  dbsubcelltype3  \
# 16849  BLOODVESSELCELL              0               0               0
# 16850  BLOODVESSELCELL              0               0               0
# 17020  BLOODVESSELCELL              0               0               0
# 17483  BLOODVESSELCELL              0               0               0
# 18022  BLOODVESSELCELL              0               0               0
# 18033  BLOODVESSELCELL              0               0               0
# 18139  BLOODVESSELCELL              0               0               0
# 18377  BLOODVESSELCELL              0               0               0
# 18379  BLOODVESSELCELL              0               0               0
# 18401  BLOODVESSELCELL              0               0               0
# 18580  BLOODVESSELCELL              0               0               0
# 18657  BLOODVESSELCELL              0               0               0
# 18688  BLOODVESSELCELL              0               0               0
# 19364  BLOODVESSELCELL              0               0               0
# 19497  BLOODVESSELCELL              0               0               0
# 19498  BLOODVESSELCELL              0               0               0
# 19621  BLOODVESSELCELL              0               0               0
# 19672  BLOODVESSELCELL              0               0               0
# 19673  BLOODVESSELCELL              0               0               0
# 19696  BLOODVESSELCELL              0               0               0
#
#        nrvoxels  circulardepth
# 16849        32           2880
# 16850        32           2919
# 17020        40           2488
# 17483        73            638
# 18022        19            961
# 18033        22           2939
# 18139        34           2189
# 18377        45           2939
# 18379        45           2459
# 18401        46           2929
# 18580        53           3155
# 18657        57            836
# 18688        59           2229
# 19364        29           2928
# 19497        38           1851
# 19498        38           2330
# 19621        43           2702
# 19672        45           2959
# 19673        45           2735
# 19696        46           1568

# %%
excluded_df.dbcelltype.unique()
# Out:
# array(['UNKNOWN0', 'BLOODVESSELCELL', 'PYRAMIDAL', 'MG_OPC', 'OLIGO',
#        'ASTROCYTE'], dtype=object)

# %%
df = pd.merge(annoDf, cbDf, on=['dbcellid', 'x', 'y', 'z'], how="left")
df
# Out:
#        dbcellid       x       y     z  goog14r0seg1_baseid  google_aggloid  \
# 0         49363       0       0     0                    0               0
# 1         49364       0       0     0                    0               0
# 2         49365       0       0     0                    0               0
# 3         49366       0       0     0                    0               0
# 4         49367       0       0     0                    0               0
# ...         ...     ...     ...   ...                  ...             ...
# 49372     17501  235985  191385  1921          22977375653     40591466610
# 49373     48840  205304  143482  5249          65497765963     91991908616
# 49374     38326  319163  249034   131           6035046399      7054269922
# 49375     21002  267462  136502  2691          38772897807     47623659810
# 49376     27863  391015   90796  3303          37408801249     54950076961
#
#                dbcelltype  dbsubcelltype  dbsubcelltype2  dbsubcelltype3  ...  \
# 0                UNKNOWN0              0               0               0  ...
# 1                UNKNOWN0              0               0               0  ...
# 2                UNKNOWN0              0               0               0  ...
# 3                UNKNOWN0              0               0               0  ...
# 4                UNKNOWN0              0               0               0  ...
# ...                   ...            ...             ...             ...  ...
# 49372           ASTROCYTE              0               0               0  ...
# 49373           ASTROCYTE              0               0               0  ...
# 49374  UNCLASSIFIEDNEURON             16               0               0  ...
# 49375              MG_OPC              0               0               0  ...
# 49376         INTERNEURON              0               0               0  ...
#
#        circulardepth  type      xmin      ymin    zmin      xmax      ymax  \
# 0                780   NaN       NaN       NaN     NaN       NaN       NaN
# 1                780   NaN       NaN       NaN     NaN       NaN       NaN
# 2                780   NaN       NaN       NaN     NaN       NaN       NaN
# 3                780   NaN       NaN       NaN     NaN       NaN       NaN
# 4                780   NaN       NaN       NaN     NaN       NaN       NaN
# ...              ...   ...       ...       ...     ...       ...       ...
# 49372           1975   1.0  235264.0  190592.0  1792.0  236671.0  192511.0
# 49373           1821   1.0  204800.0  142656.0  5120.0  205951.0  144319.0
# 49374           1644   1.0  317632.0  248128.0   128.0  320959.0  250111.0
# 49375           1483   1.0  267136.0  135872.0  2688.0  267711.0  137215.0
# 49376            512   1.0  390528.0   90176.0  3200.0  391807.0   91903.0
#
#          zmax       volume  dbcelltype_code
# 0         NaN          NaN              NaN
# 1         NaN          NaN              NaN
# 2         NaN          NaN              NaN
# 3         NaN          NaN              NaN
# 4         NaN          NaN              NaN
# ...       ...          ...              ...
# 49372  2063.0  1081.828442              4.0
# 49373  5263.0   524.858425              4.0
# 49374   399.0  2183.588217             10.0
# 49375  2831.0   195.991437              6.0
# 49376  3471.0   907.982930              2.0
#
# [49377 rows x 21 columns]

# %%
# df.to_csv('merged_df.csv', index=False)

# %% [markdown]
# # Create data for nucleus_table

# %%
df = cbDf[cbDf.type==1].copy()

# %%
# upload random annotations
nrow = df.shape[0]
pt_position = df.apply(lambda row : np.array([row['x'], row['y'], row['z']]), axis=1)
bb_start_position = df.apply(lambda row : np.array([row['xmin'], row['ymin'], row['zmin']]), axis=1)
bb_end_position = df.apply(lambda row : np.array([row['xmax'], row['ymax'], row['zmax']]), axis=1)

data = pd.DataFrame.from_dict({
    'id': df.dbcellid.tolist(),
    'valid': np.repeat(True, nrow),
    'volume': df.volume.tolist(),
    'pt_position': pt_position,
    'bb_start_position': bb_start_position,
    'bb_end_position': bb_end_position
})

# %%
len(data.id.unique())
# Out:
# 49108

# %%
data.shape
# Out:
# (49108, 6)

# %%
duplicate_ids = data[data.duplicated('id')]
duplicate_ids
# Out:
# Empty DataFrame
# Columns: [id, valid, volume, pt_position, bb_start_position, bb_end_position]
# Index: []

# %%
duplicate_ids = cbDf[cbDf.duplicated('dbcellid')]
duplicate_ids
# Out:
#        type  dbcellid       x       y     z    xmin    ymin  zmin    xmax  \
# 49108     2         1  224320  234816   544  224064  234304   416  224703
# 49109     2         2  220352  235008    32  220096  234624    32  220927
# 49110     2         3  271296  132352  4640  270912  131968  4448  271743
# 49111     2         4  272704  158848   160  272128  158528     0  273535
# 49112     2         5  271616  152000   352  271360  151168   192  271871
# ...     ...       ...     ...     ...   ...     ...     ...   ...     ...
# 57307     2      8209  154579  154504  4224  154240  154048  4128  154879
# 57308     2      8210  277041  149728   992  276800  148352   864  277759
# 57309     2      8211  276946  148654   992  276864  147840   704  277631
# 57310     2      8212  273233  181627  5280  273152  181248  5248  273727
# 57311     2      8213  448208  165140  1600  448000  164928  1600  448639
#
#          ymax  zmax      volume  dbcelltype_code
# 49108  235263   655  120.695292               11
# 49109  235391   143   63.115887               11
# 49110  132735  4783   95.227478               17
# 49111  159167   271  107.407737               17
# 49112  152639   399  114.051514               17
# ...       ...   ...         ...              ...
# 57307  154943  4335   80.832627               11
# 57308  149823  1007   90.798293               15
# 57309  148799  1007   81.939923               15
# 57310  182463  5295   40.969961               12
# 57311  165631  1839   84.154515               11
#
# [8202 rows x 13 columns]

# %%
data[data.id==1]
# Out:
#        id  valid       volume                   pt_position  \
# 0       1   True  8825.151160  [259891.0, 165404.0, 1408.0]
# 49108   1   True   120.695292   [224320.0, 234816.0, 544.0]
#
#                  bb_start_position               bb_end_position
# 0      [258240.0, 163392.0, 896.0]  [262335.0, 167167.0, 1551.0]
# 49108  [224064.0, 234304.0, 416.0]   [224703.0, 235263.0, 655.0]

# %%
cbDf[cbDf.dbcellid==1]
# Out:
#        type  dbcellid       x       y     z    xmin    ymin  zmin    xmax  \
# 0         1         1  259891  165404  1408  258240  163392   896  262335
# 49108     2         1  224320  234816   544  224064  234304   416  224703
#
#          ymax  zmax       volume  dbcelltype_code
# 0      167167  1551  8825.151160                1
# 49108  235263   655   120.695292               11

# %%
data
# Out:
#           id  valid       volume                   pt_position  \
# 0          1   True  8825.151160  [259891.0, 165404.0, 1408.0]
# 1          2   True  5967.219524  [261308.0, 171181.0, 1024.0]
# 2          3   True  3984.051929  [256788.0, 171573.0, 1408.0]
# 3          4   True  3402.721395  [254675.0, 164220.0, 1280.0]
# 4          5   True  2142.618255  [258308.0, 160604.0, 1536.0]
# ...      ...    ...          ...                           ...
# 49103  49388   True   194.884141   [271886.0, 57646.0, 5120.0]
# 49104  49389   True   200.420622   [262818.0, 57594.0, 3328.0]
# 49105  49390   True   215.922770  [323024.0, 273066.0, 4480.0]
# 49106  49391   True    77.510738      [94468.0, 203091.0, 0.0]
# 49107  49392   True   142.841217   [88936.0, 199621.0, 5248.0]
#
#                   bb_start_position               bb_end_position
# 0       [258240.0, 163392.0, 896.0]  [262335.0, 167167.0, 1551.0]
# 1       [259968.0, 169856.0, 512.0]  [262463.0, 172543.0, 1295.0]
# 2      [255552.0, 170688.0, 1152.0]  [258367.0, 173119.0, 1679.0]
# 3      [253376.0, 163072.0, 1152.0]  [255679.0, 165375.0, 1679.0]
# 4      [257472.0, 159744.0, 1408.0]  [259327.0, 161791.0, 1807.0]
# ...                             ...                           ...
# 49103   [271552.0, 56960.0, 4992.0]   [272191.0, 58175.0, 5135.0]
# 49104   [262528.0, 57088.0, 3200.0]   [263295.0, 58047.0, 3343.0]
# 49105  [322560.0, 272512.0, 4480.0]  [323839.0, 273599.0, 4623.0]
# 49106      [94208.0, 202752.0, 0.0]     [94783.0, 203455.0, 15.0]
# 49107   [88832.0, 199488.0, 5248.0]   [89471.0, 200575.0, 5263.0]
#
# [49108 rows x 6 columns]

# %%
cbDf[cbDf.type==2]
# Out:
#        type  dbcellid       x       y     z    xmin    ymin  zmin    xmax  \
# 49108     2         1  224320  234816   544  224064  234304   416  224703
# 49109     2         2  220352  235008    32  220096  234624    32  220927
# 49110     2         3  271296  132352  4640  270912  131968  4448  271743
# 49111     2         4  272704  158848   160  272128  158528     0  273535
# 49112     2         5  271616  152000   352  271360  151168   192  271871
# ...     ...       ...     ...     ...   ...     ...     ...   ...     ...
# 57307     2      8209  154579  154504  4224  154240  154048  4128  154879
# 57308     2      8210  277041  149728   992  276800  148352   864  277759
# 57309     2      8211  276946  148654   992  276864  147840   704  277631
# 57310     2      8212  273233  181627  5280  273152  181248  5248  273727
# 57311     2      8213  448208  165140  1600  448000  164928  1600  448639
#
#          ymax  zmax      volume  dbcelltype_code
# 49108  235263   655  120.695292               11
# 49109  235391   143   63.115887               11
# 49110  132735  4783   95.227478               17
# 49111  159167   271  107.407737               17
# 49112  152639   399  114.051514               17
# ...       ...   ...         ...              ...
# 57307  154943  4335   80.832627               11
# 57308  149823  1007   90.798293               15
# 57309  148799  1007   81.939923               15
# 57310  182463  5295   40.969961               12
# 57311  165631  1839   84.154515               11
#
# [8204 rows x 13 columns]

# %%
data.to_hdf('../data/h01_nucleus_table_data.h5', key='data', mode='w')
# Out:
# /var/folders/s8/gtdvyq2j6dscgs2kz2cvbfqw0000gn/T/ipykernel_29653/1923134292.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['pt_position', 'bb_start_position', 'bb_end_position'], dtype='object')]
#
#   data.to_hdf('../data/h01_nucleus_table_data.h5', key='data', mode='w')

# %%
test = pd.read_hdf('../data/h01_nucleus_table_data.h5', 'data')

# %%
test.shape
# Out:
# (49108, 6)

# %%
test.head()
# Out:
#    id  valid       volume                   pt_position  \
# 0   1   True  8825.151160  [259891.0, 165404.0, 1408.0]
# 1   2   True  5967.219524  [261308.0, 171181.0, 1024.0]
# 2   3   True  3984.051929  [256788.0, 171573.0, 1408.0]
# 3   4   True  3402.721395  [254675.0, 164220.0, 1280.0]
# 4   5   True  2142.618255  [258308.0, 160604.0, 1536.0]
#
#               bb_start_position               bb_end_position
# 0   [258240.0, 163392.0, 896.0]  [262335.0, 167167.0, 1551.0]
# 1   [259968.0, 169856.0, 512.0]  [262463.0, 172543.0, 1295.0]
# 2  [255552.0, 170688.0, 1152.0]  [258367.0, 173119.0, 1679.0]
# 3  [253376.0, 163072.0, 1152.0]  [255679.0, 165375.0, 1679.0]
# 4  [257472.0, 159744.0, 1408.0]  [259327.0, 161791.0, 1807.0]

# %%
test.iloc[0].pt_position
# Out:
# array([259891., 165404.,   1408.])

# %% [markdown]
# # Create cell_type_local table

# %%
df = pd.merge(annoDf, cbDf, on=['dbcellid', 'x', 'y', 'z'], how="left")

# %%
# upload random annotations
nrow = df.shape[0]
pt_position = df.apply(lambda row : np.array([row['x'], row['y'], row['z']]), axis=1)
classification_system = df.apply(lambda row: ', '.join([str(row['dbsubcelltype']), str(row['dbsubcelltype2']), str(row['dbsubcelltype3'])]), axis=1)

cellData = pd.DataFrame.from_dict({
    'valid': np.repeat(True, nrow),
    'classification_system': classification_system,
    'cell_type': df.dbcelltype.tolist(),
    'pt_position': pt_position,
})

# %%
cellData
# Out:
#        valid classification_system           cell_type             pt_position
# 0       True               0, 0, 0            UNKNOWN0               [0, 0, 0]
# 1       True               0, 0, 0            UNKNOWN0               [0, 0, 0]
# 2       True               0, 0, 0            UNKNOWN0               [0, 0, 0]
# 3       True               0, 0, 0            UNKNOWN0               [0, 0, 0]
# 4       True               0, 0, 0            UNKNOWN0               [0, 0, 0]
# ...      ...                   ...                 ...                     ...
# 49372   True               0, 0, 0           ASTROCYTE  [235985, 191385, 1921]
# 49373   True               0, 0, 0           ASTROCYTE  [205304, 143482, 5249]
# 49374   True              16, 0, 0  UNCLASSIFIEDNEURON   [319163, 249034, 131]
# 49375   True               0, 0, 0              MG_OPC  [267462, 136502, 2691]
# 49376   True               0, 0, 0         INTERNEURON   [391015, 90796, 3303]
#
# [49377 rows x 4 columns]

# %%
cellData.to_hdf('../data/dbcells_dump_table_data.h5', key='data', mode='w')
# Out:
# /var/folders/s8/gtdvyq2j6dscgs2kz2cvbfqw0000gn/T/ipykernel_29653/2805138277.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['classification_system', 'cell_type', 'pt_position'], dtype='object')]
#
#   cellData.to_hdf('../data/dbcells_dump_table_data.h5', key='data', mode='w')

# %% [markdown]
# # CAVEclient

# %%
url = "https://global.brain-wire-test.org/"
datastack = "h01_c3_flat"
token = "3ac8d9f0de1b192dba9c085114f0f811"

# %%
client = CAVEclient(datastack_name=datastack, server_address=url, auth_token=token)

# %%
client.info.get_datastacks()
# Out:
# ['h01_c3_flat']

# %%
# get existing tables
all_tables = client.annotation.get_tables()
all_tables
# Out:
# ['nucleus_test_table2',
#  'nucleus_test_table',
#  'nucleus_table',
#  'dbcells_dump',
#  'test_table',
#  'test_table2']

# %% [markdown]
# ## Upload nucleus data

# %%
import time
chunk_size = 10000  # Number of rows per chunk
i = 40000 # 0 

# for i in range(start, len(data), chunk_size):
chunk = data.iloc[i:i+chunk_size]
client.annotation.post_annotation_df(table_name='nucleus_table',
                                     df = chunk,
                                     position_columns=["pt_position", "bb_start_position", "bb_end_position"])
#     time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 7>()
#       5 # for i in range(start, len(data), chunk_size):
#       6 chunk = data.iloc[i:i+chunk_size]
# ----> 7 client.annotation.post_annotation_df(table_name='nucleus_table',
#       8                                      df = chunk,
#       9                                      position_columns=["pt_position", "bb_start_position", "bb_end_position"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/annotationengine.py:607, in AnnotationClientV2.post_annotation_df(self, table_name, df, position_columns, aligned_volume_name)
#     603     aligned_volume_name = self.aligned_volume_name
#     605 data = self.process_position_columns(df, position_columns)
# --> 607 return self.post_annotation(
#     608     table_name, data, aligned_volume_name=aligned_volume_name
#     609 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/annotationengine.py:536, in AnnotationClientV2.post_annotation(self, table_name, data, aligned_volume_name)
#     529 data = {"annotations": data}
#     531 response = self.session.post(
#     532     url,
#     533     data=json.dumps(data, cls=BaseEncoder),
#     534     headers={"Content-Type": "application/json"},
#     535 )
# --> 536 return handle_response(response)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/base.py:81, in handle_response(response, as_json, log_warning)
#      79 def handle_response(response, as_json=True, log_warning=True):
#      80     """Deal with potential errors in endpoint response and return json for default case"""
# ---> 81     _raise_for_status(response, log_warning=log_warning)
#      82     _check_authorization_redirect(response)
#      83     if as_json:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/base.py:72, in _raise_for_status(r, log_warning)
#      64     http_error_msg = "%s Server Error: %s for url: %s content:%s" % (
#      65         r.status_code,
#      66         reason,
#      67         r.url,
#      68         r.content,
#      69     )
#      71 if http_error_msg:
# ---> 72     raise requests.HTTPError(http_error_msg, response=r)
#      73 if log_warning:
#      74     warning = r.headers.get("Warning")
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: https://local.brain-wire-test.org/annotation/api/v2/aligned_volume/h01/table/nucleus_table/annotations content:b'{"message": "Internal Server Error"}\n'

# %% [markdown]
# ## Upload annotation data

# %%
cellData.head()
# Out:
#    valid classification_system cell_type pt_position
# 0   True               0, 0, 0  UNKNOWN0   [0, 0, 0]
# 1   True               0, 0, 0  UNKNOWN0   [0, 0, 0]
# 2   True               0, 0, 0  UNKNOWN0   [0, 0, 0]
# 3   True               0, 0, 0  UNKNOWN0   [0, 0, 0]
# 4   True               0, 0, 0  UNKNOWN0   [0, 0, 0]

# %%
cellData.tail()
# Out:
#        valid classification_system           cell_type             pt_position
# 49372   True               0, 0, 0           ASTROCYTE  [235985, 191385, 1921]
# 49373   True               0, 0, 0           ASTROCYTE  [205304, 143482, 5249]
# 49374   True              16, 0, 0  UNCLASSIFIEDNEURON   [319163, 249034, 131]
# 49375   True               0, 0, 0              MG_OPC  [267462, 136502, 2691]
# 49376   True               0, 0, 0         INTERNEURON   [391015, 90796, 3303]

# %%
cellData.shape
# Out:
# (49377, 4)

# %%
import time
chunk_size = 10000  # Number of rows per chunk
i = 40000 # 0
# start = 0

# for i in range(start, len(data), chunk_size):
chunk = cellData.iloc[i:i+chunk_size]
client.annotation.post_annotation_df(table_name='dbcells_dump',
                                         df = chunk,
                                         position_columns=["pt_position"])
#     time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 8>()
#       4 # start = 0
#       5
#       6 # for i in range(start, len(data), chunk_size):
#       7 chunk = cellData.iloc[i:i+chunk_size]
# ----> 8 client.annotation.post_annotation_df(table_name='dbcells_dump',
#       9                                          df = chunk,
#      10                                          position_columns=["pt_position"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/annotationengine.py:607, in AnnotationClientV2.post_annotation_df(self, table_name, df, position_columns, aligned_volume_name)
#     603     aligned_volume_name = self.aligned_volume_name
#     605 data = self.process_position_columns(df, position_columns)
# --> 607 return self.post_annotation(
#     608     table_name, data, aligned_volume_name=aligned_volume_name
#     609 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/annotationengine.py:536, in AnnotationClientV2.post_annotation(self, table_name, data, aligned_volume_name)
#     529 data = {"annotations": data}
#     531 response = self.session.post(
#     532     url,
#     533     data=json.dumps(data, cls=BaseEncoder),
#     534     headers={"Content-Type": "application/json"},
#     535 )
# --> 536 return handle_response(response)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/base.py:81, in handle_response(response, as_json, log_warning)
#      79 def handle_response(response, as_json=True, log_warning=True):
#      80     """Deal with potential errors in endpoint response and return json for default case"""
# ---> 81     _raise_for_status(response, log_warning=log_warning)
#      82     _check_authorization_redirect(response)
#      83     if as_json:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/caveclient/base.py:72, in _raise_for_status(r, log_warning)
#      64     http_error_msg = "%s Server Error: %s for url: %s content:%s" % (
#      65         r.status_code,
#      66         reason,
#      67         r.url,
#      68         r.content,
#      69     )
#      71 if http_error_msg:
# ---> 72     raise requests.HTTPError(http_error_msg, response=r)
#      73 if log_warning:
#      74     warning = r.headers.get("Warning")
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: https://local.brain-wire-test.org/annotation/api/v2/aligned_volume/h01/table/dbcells_dump/annotations content:b'{"message": "Internal Server Error"}\n'

# %% [markdown]
# ## Get Data

# %%
client.annotation.get_annotation(table_name="nucleus_table",
                                 annotation_ids=[10003])
# Out:
# [{'bb_start_position': [264768, 159232, 0],
#   'valid': True,
#   'pt_position': [265650, 160169, 0],
#   'volume': 1247.922880512,
#   'bb_end_position': [266559, 161535, 271],
#   'id': 10003,
#   'created': '2023-05-25 18:32:25.244568',
#   'deleted': 'None',
#   'superceded_id': None}]

# %%
client.annotation.get_annotation(table_name="dbcells_dump",
                                 annotation_ids=[1])
# Out:
# [{'valid': True,
#   'pt_position': [0, 0, 0],
#   'classification_system': '0, 0, 0',
#   'cell_type': 'UNKNOWN0',
#   'deleted': 'None',
#   'superceded_id': None,
#   'created': '2023-05-25 20:37:02.935764',
#   'id': 1}]

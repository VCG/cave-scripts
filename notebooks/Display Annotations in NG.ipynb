# %% [markdown]
# # H01

# %%
from nglui.statebuilder import *
from caveclient import CAVEclient

# %%
url = "https://global.brain-wire-test.org/"
datastack = "h01_c3_flat"
client = CAVEclient(datastack_name=datastack, server_address=url)

# %% [markdown]
# ### Get Annotations from Materialized Table

# %%
annotationsDf = client.materialize.query_table(table="cells",
                                              desired_resolution=[4,4,40]
                                              )

# %% [markdown]
# > https://caveclient.readthedocs.io/en/latest/guide/materialization.html#desired-resolution
# If you want positions in 4,4,40nm voxel coordinates to use with cloud-volume or neuroglancer you would pass desired_resolution=[4,4,40].

# %%
annotationsDf.tail()
# Out:
#           id                          created  superceded_id valid  \
# 49372  49373 2023-06-15 19:29:36.516592+00:00            NaN     t
# 49373  49374 2023-06-15 19:29:36.517171+00:00            NaN     t
# 49374  49375 2023-06-15 19:29:36.517764+00:00            NaN     t
# 49375  49376 2023-06-15 19:29:36.518349+00:00            NaN     t
# 49376  49377 2023-06-15 19:29:36.518931+00:00            NaN     t
#
#       classification_system           cell_type    pt_supervoxel_id  \
# 49372               0, 0, 0           ASTROCYTE  104452849731108865
# 49373               0, 0, 0           ASTROCYTE  100224335913943043
# 49374              16, 0, 0  UNCLASSIFIEDNEURON  115930719393415168
# 49375               0, 0, 0              MG_OPC  108808359288766465
# 49376               0, 0, 0         INTERNEURON  125761110870589440
#
#                pt_root_id                     pt_position
# 49372  864691132482582976  [471970.0, 382770.0, 1584.825]
# 49373  864691132258960726  [410608.0, 286964.0, 4330.425]
# 49374  864691132393049686   [638326.0, 498068.0, 108.075]
# 49375  864691132207193954  [534924.0, 273004.0, 2220.075]
# 49376  864691132401212067  [782030.0, 181592.0, 2724.975]

# %% [markdown]
# ### Create neuroglancer state

# %%
img_source = client.info.image_source()
img_layer = ImageLayerConfig(name='h01', source=img_source)

# %%
# seg_source = client.info.segmentation_source()
# seg_layer = SegmentationLayerConfig(name="segs", source=seg_source)

# %%
points = PointMapper(point_column="pt_position")
anno_layer = AnnotationLayerConfig(name="annos", mapping_rules=[points])

# %%
sb = StateBuilder([img_layer, anno_layer], url_prefix='https://ngl.cave-explorer.org/')
d = sb.render_state(annotationsDf[1000:1500], 
                    return_as='dict', 
                    compatibility_mode=True, 
                    url_prefix='https://ngl.cave-explorer.org/')

# %%
# set dimensions for annotation layer
d['layers'][1]['source'][0]['transform']['outputDimensions']={
            "x": [
              4e-9,
              "m"
            ],
            "y": [
              4e-9,
              "m"
            ],
            "z": [
              3.3e-8,
              "m"
            ]
          }

# %%
d['crossSectionScale']=7.5e-8 # -> it is weird. 7.5e-8 is 7.5um, not 0.075um.

# %%
d
# Out:
# OrderedDict([('selectedLayer',
#               OrderedDict([('layer', 'annos'), ('visible', True)])),
#              ('showSlices', False),
#              ('layout', 'xy-3d'),
#              ('crossSectionScale', 7.5e-08),
#              ('projectionScale', 2000.0),
#              ('layers',
#               [OrderedDict([('type', 'image'),
#                             ('source',
#                              [{'url': 'precomputed://gs://h01-release/data/20210601/4nm_raw'}]),
#                             ('name', 'h01')]),
#                OrderedDict([('type', 'annotation'),
#                             ('source',
#                              [OrderedDict([('url', 'local://annotations'),
#                                            ('transform',
#                                             OrderedDict([('outputDimensions',
#                                                           {'x': [4e-09, 'm'],
#                                                            'y': [4e-09, 'm'],
#                                                            'z': [3.3e-08,
#                                                             'm']})]))])]),
#                             ('linkedSegmentationLayer', OrderedDict()),
#                             ('annotations',
#                              [OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [447592.0, 376708.0, 211.0]),
#                                            ('id',
#                                             'bb0d49fca758a05a8fc47700ac26bd7c395e042e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [509308.0, 473286.0, 211.0]),
#                                            ('id',
#                                             '33fb7417eaaf71f0623fd8da571ad6cbfe1ead2b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [434124.0, 535284.0, 211.0]),
#                                            ('id',
#                                             '82d7f1b23d5ead3a88b3125c7a625859689f9e4a')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [684066.0, 294344.0, 211.0]),
#                                            ('id',
#                                             'f0a7523ea52513289ee9154b309084d6fae407ea')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [756434.0, 305408.0, 211.0]),
#                                            ('id',
#                                             '1b5028ee5330a4c1e225ea031b986a08dca7ddab')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [232182.0, 473892.0, 211.0]),
#                                            ('id',
#                                             '5c646d0fa34f3ddb4544c238623c69805d58e2e7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [190558.0, 566032.0, 211.0]),
#                                            ('id',
#                                             'daabd50ba53bfb60faff94a500ad5f53952dfa3c')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [803552.0, 179322.0, 211.0]),
#                                            ('id',
#                                             'd446048f7e798bf79dc77230be0a991cb2175a8d')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [205790.0, 464524.0, 211.0]),
#                                            ('id',
#                                             '5998e84dff9d616e5674e32ab8014bbed126edc8')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [756590.0, 94118.0, 211.0]),
#                                            ('id',
#                                             'a7e4004981feeadf510fa9d4bb52648c4dd2ed4e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [234930.0, 512544.0, 211.0]),
#                                            ('id',
#                                             '53420bb025435be60030b84a4027939f566bc5c8')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [209924.0, 526422.0, 211.0]),
#                                            ('id',
#                                             '059dd648ebda6cea9b13d1c8bce7b46a9b81d79e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [174060.0, 504758.0, 211.0]),
#                                            ('id',
#                                             '70790d99b55c559f21ad7567d60cce86eafd3ce7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [161382.0, 484762.0, 211.0]),
#                                            ('id',
#                                             'b5fdefc6162d8c5ba92c1bbc871d551429d7842a')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [158666.0, 484696.0, 211.0]),
#                                            ('id',
#                                             'c8ae5eac5a0dee4d5130d49cc0ae842ac84616ed')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [169644.0, 502936.0, 211.0]),
#                                            ('id',
#                                             '17309b724dcf54f697b650c8a391bbfcc9d6153e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [351142.0, 507972.0, 211.0]),
#                                            ('id',
#                                             '11874e9aa9ba71bb88d8c67a6ef8b6b6ba497015')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [258862.0, 525580.0, 211.0]),
#                                            ('id',
#                                             '4b2702a1952aa83800665924b6989efaea9116eb')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [263856.0, 536560.0, 211.0]),
#                                            ('id',
#                                             'e3af5857df1cf8e5d726f9ee49da412c28352441')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [154626.0, 571160.0, 211.0]),
#                                            ('id',
#                                             'f7c8c7920ea167f3bea5b9fe9e3594a7ee001556')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [771726.0, 377410.0, 211.0]),
#                                            ('id',
#                                             'c6d1209496877839aed84b2f7e2d60ddb66bb82d')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [368716.0, 415250.0, 211.0]),
#                                            ('id',
#                                             'cf14ba80ebab2bf6166a56e4f5ec432d27680183')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [462922.0, 264264.0, 211.0]),
#                                            ('id',
#                                             '3a6aad862d45621c5108e36b97562af34b12d65c')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [441692.0, 362776.0, 211.0]),
#                                            ('id',
#                                             'd1862daa63c3c34b62dfa918c82f0594dc7d7c57')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [526930.0, 378752.0, 211.0]),
#                                            ('id',
#                                             '7fb50d3a7e500122cd6c4a7adda724499790e8fa')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [381452.0, 474880.0, 211.0]),
#                                            ('id',
#                                             'ef53dd995ddcc02c395a7b6e66d0a440a7daff8e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [694032.0, 396980.0, 211.0]),
#                                            ('id',
#                                             'ec11ba2f2c10ea2a1c9a4880d8c90a07b690a232')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [461342.0, 382020.0, 211.0]),
#                                            ('id',
#                                             'ba73af49b8f4ec17b892fbab0a90c3e48ead28eb')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [634878.0, 469660.0, 211.0]),
#                                            ('id',
#                                             '78f5783675ebf743f9fffc9065e0da85e4623fb6')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [281086.0, 527462.0, 211.0]),
#                                            ('id',
#                                             'ec9d4f2a8f361aac48e342dbd9c1260c7e1f9a38')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [415738.0, 495230.0, 211.0]),
#                                            ('id',
#                                             '8433258d91ed42953d88756f58a0ca44f20a3ab3')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [229848.0, 392384.0, 211.0]),
#                                            ('id',
#                                             'a24b15fb7675d0ec5a108284c0325e990d105f3b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [642784.0, 340088.0, 211.0]),
#                                            ('id',
#                                             '8ddbd1069cd19f2c7f2f958621f77340f77e2dee')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [192310.0, 459574.0, 211.0]),
#                                            ('id',
#                                             'f0901535c29a9eaf518799500713311fe1fe22b5')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [159218.0, 489442.0, 211.0]),
#                                            ('id',
#                                             '70f9cc9442d98ebaef75bfe64484c550d0f9d201')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [182562.0, 479892.0, 211.0]),
#                                            ('id',
#                                             'f919318257671c87b5599429507c41c700cfb54f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [161636.0, 469100.0, 211.0]),
#                                            ('id',
#                                             '6e3230c58b4d5d66bd6dd1785076fc80cd6f4584')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [162638.0, 408692.0, 211.0]),
#                                            ('id',
#                                             'dec1ff9bfc8bb6470e58cfd6a38bae4303d5102d')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [538522.0, 155242.0, 211.0]),
#                                            ('id',
#                                             '5ed128ae9bd65212850d7ba48f0e845ee3c86047')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [178732.0, 561944.0, 211.0]),
#                                            ('id',
#                                             '90987e646beb2dcf546c97ddcdad400cc99d074c')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [148712.0, 576040.0, 211.0]),
#                                            ('id',
#                                             '86b5deaddf63711bda9f17ee98440030666852da')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [160362.0, 575634.0, 211.0]),
#                                            ('id',
#                                             '8922ddfbcd6f0ca7455b83a112e73642339f30b7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [234692.0, 357960.0, 211.0]),
#                                            ('id',
#                                             '2749e748c868b7eca43c65d793514ee39a28c845')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [436678.0, 244778.0, 211.0]),
#                                            ('id',
#                                             'e82b8c62f54f19ae0212a66b5b789b879ccf42e7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [639304.0, 296368.0, 211.0]),
#                                            ('id',
#                                             '7a8ea87f79188c39c579f13426eb2346d70c35c1')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [458676.0, 306896.0, 211.0]),
#                                            ('id',
#                                             'c81a91bfbe8b943c4a2b50830a9fcd2f66860f8e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [354218.0, 360928.0, 211.0]),
#                                            ('id',
#                                             '4018cc02764579ebb3c5b01f959bfdef46dd8628')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [480178.0, 355324.0, 211.0]),
#                                            ('id',
#                                             'bb77e481b2035c4ca2fa01251d414c8b55eb2846')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [273282.0, 401130.0, 211.0]),
#                                            ('id',
#                                             '21cd558eed318f224ec89350d3a5392d646e2780')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [405436.0, 319908.0, 211.0]),
#                                            ('id',
#                                             'cd136b448914d68adc6e3d97e2aa7c8323f65e92')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [512638.0, 428808.0, 211.0]),
#                                            ('id',
#                                             '57f7013ce25780ee340d7f13a7420475da132310')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [499552.0, 405496.0, 211.0]),
#                                            ('id',
#                                             '99fffea4bfca5ac0d6d1a337ac04630e7c8e7d84')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [617956.0, 353348.0, 211.0]),
#                                            ('id',
#                                             'f7df1fe3f72b63383c3c36f9807b415eceb31e2d')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [713518.0, 250440.0, 211.0]),
#                                            ('id',
#                                             '860f5f25b96a01ab1701bead0b5d54815e98b4af')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [590386.0, 242778.0, 211.0]),
#                                            ('id',
#                                             '5f0a4dbfdefda771c9bd14793f8b83f2fd738e9f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [439428.0, 524240.0, 211.0]),
#                                            ('id',
#                                             'd98f2864fde77465a1ed9f3c5d7b6db50d235c4b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [763630.0, 249148.0, 211.0]),
#                                            ('id',
#                                             'ba5453a0933de9e1df97ccf2eed5a13b0d19b912')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [410492.0, 495878.0, 211.0]),
#                                            ('id',
#                                             'affc1dda79442688aa43ae68dbd6c192487aab84')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [198654.0, 459024.0, 211.0]),
#                                            ('id',
#                                             '120d2602250e92ee90c18da3318f6286ca64a2a0')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [234752.0, 473166.0, 211.0]),
#                                            ('id',
#                                             'fe86efd9db78a8e97c9be692a064590a220a5b2a')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [250966.0, 433248.0, 211.0]),
#                                            ('id',
#                                             '3d13a33beb8c79310240a6377700d8a855793661')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [176302.0, 490372.0, 211.0]),
#                                            ('id',
#                                             '5e4f9d6fefa0a68ecd1194447787782f1e6b845b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [174828.0, 567606.0, 211.0]),
#                                            ('id',
#                                             '738e8f62a8a7fb5f8c51cf6173c5e03eb9105f97')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [245146.0, 375410.0, 211.0]),
#                                            ('id',
#                                             '96a52bd13ad12c69a044915ad51df4786de08bbb')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [311096.0, 324074.0, 211.0]),
#                                            ('id',
#                                             'b7323eea99f92a179b773e4e0e7bb3d07c73c058')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [471308.0, 363962.0, 211.0]),
#                                            ('id',
#                                             '86a3744afef1fa1c619b1260c7ebbfb89d8ab9b0')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [263396.0, 407716.0, 211.0]),
#                                            ('id',
#                                             '22ef95e282683f0410e413683ebf898a7a5518ab')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [540646.0, 432232.0, 211.0]),
#                                            ('id',
#                                             'c9b41a19643fec5784535dc301353b0e19eac5f0')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [582324.0, 369420.0, 211.0]),
#                                            ('id',
#                                             'd7797eff888466901e949e673e6259a6c13de0ea')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [583658.0, 357948.0, 211.0]),
#                                            ('id',
#                                             '5c9c565b3469144e5d936321c18442996f3df286')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [301374.0, 496514.0, 211.0]),
#                                            ('id',
#                                             'dc51a7e11d82a32da9e00f1603983d97e42dedee')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [459880.0, 251712.0, 211.0]),
#                                            ('id',
#                                             'bbedafd57465ae1cc3eb7a369edfe776e85d3921')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [590612.0, 245154.0, 211.0]),
#                                            ('id',
#                                             '56fd332f11d1d7977ee0443058a49082bc4a4ab4')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [650072.0, 247842.0, 211.0]),
#                                            ('id',
#                                             '093f9cf1a6a7e6100dbf386e65fdd88e19c7bcf7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [654318.0, 104356.0, 211.0]),
#                                            ('id',
#                                             'ecaff6856574d12a753f85ecb0612f5429b24f99')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [538764.0, 254976.0, 211.0]),
#                                            ('id',
#                                             '45507fface16dff084a13f60b67b21a76ca42dcf')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [301596.0, 530150.0, 211.0]),
#                                            ('id',
#                                             '21b5d39405140ddcb5b10e20a61b283a061fca0a')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [155746.0, 498172.0, 211.0]),
#                                            ('id',
#                                             'b91e5eedd22979b5e075ec15a956934cf308337d')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [327778.0, 545216.0, 211.0]),
#                                            ('id',
#                                             '0c7290adfbdb7e3fca5e3ce59879ae6a51c9f618')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [185108.0, 484696.0, 211.0]),
#                                            ('id',
#                                             '98ee0d1d77bd911caabc909adff72c36f5da73d9')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [194928.0, 430782.0, 211.0]),
#                                            ('id',
#                                             'ddcc8c5a76295de69537df2b9de4dfc6ce7c7288')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [173906.0, 398658.0, 211.0]),
#                                            ('id',
#                                             '6459e86bca4077bda95f2559e652f9d7772ff75b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [575394.0, 434654.0, 211.0]),
#                                            ('id',
#                                             '9284e8fec989d460eead788b59016fe2d50e2c7e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [248644.0, 360918.0, 211.0]),
#                                            ('id',
#                                             'e6f5000a85c6d0d2aa54f40231d0bb18014a2c0b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [417534.0, 459362.0, 211.0]),
#                                            ('id',
#                                             '391918140e7e92e4d2fb1deb8bef0d49ad2d89c6')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [491730.0, 460198.0, 211.0]),
#                                            ('id',
#                                             'dc103f24058b2d95ca021d90619b4c736a132209')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [158938.0, 564604.0, 211.0]),
#                                            ('id',
#                                             '43d074cabfe80ca03ea72e5f98bf0c82cd836823')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [169234.0, 542556.0, 211.0]),
#                                            ('id',
#                                             '9debac76dfd32b22408fc37d70a78828134e491f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [152834.0, 416346.0, 211.0]),
#                                            ('id',
#                                             '61f75eac609718193cb5921d82b193c69138ed75')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [151282.0, 483474.0, 211.0]),
#                                            ('id',
#                                             'a1074ae92589bed9df25453382bb600589a04591')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [145454.0, 494876.0, 211.0]),
#                                            ('id',
#                                             '229ef0404e0b20df9fbbbfbe44c4304d2b88465b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [442150.0, 228298.0, 211.0]),
#                                            ('id',
#                                             '6f59eab1299c0a66f414361d1f0976e574e2ed8a')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [528578.0, 301380.0, 211.0]),
#                                            ('id',
#                                             'de6cec8bb524583c67f02af0f62a982738d1400b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [610076.0, 404954.0, 211.0]),
#                                            ('id',
#                                             'bfeec536a4f5e4439c805fa9d9aa8339a9c6d2db')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [511646.0, 407858.0, 211.0]),
#                                            ('id',
#                                             '1f7494aa67ad9ba457b7e89cea7f930dc2a8fa52')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [658486.0, 422014.0, 211.0]),
#                                            ('id',
#                                             '5c0b955c64f04ffc6e5a2c611a88eb961c30dcfb')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [648942.0, 247706.0, 211.0]),
#                                            ('id',
#                                             '76f8619281e4783221a76203306b86103ecc1f34')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [610282.0, 143070.0, 211.0]),
#                                            ('id',
#                                             'b52f6cdd8fd1ff2d1ea9866f373b30cc15339ff2')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [841094.0, 446818.0, 211.0]),
#                                            ('id',
#                                             '2d7b625e5ae2d01b280f442a118fe0ac5b4fc0c9')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [242594.0, 467638.0, 211.0]),
#                                            ('id',
#                                             'a8aeb17cb3f1dd08f6bda50ef49064eeaeffd2d5')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [251752.0, 552724.0, 211.0]),
#                                            ('id',
#                                             '6780ad9b196e4b46b72d3bad8f484943fa98ab4e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [273772.0, 562674.0, 211.0]),
#                                            ('id',
#                                             'dcb5efb0c41949a6fb4e8b305172bac3eebdd28f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [219770.0, 563018.0, 211.0]),
#                                            ('id',
#                                             '2252e1decdfe91e3fc3bb865d22e6c0e7b894348')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [189096.0, 561126.0, 211.0]),
#                                            ('id',
#                                             'da767d8aecfe071b11f419003fabda92ae17a36b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [153722.0, 501580.0, 211.0]),
#                                            ('id',
#                                             '89434b9e2a12ff2cc9d5c64d9d92b8f2f6b80382')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [251646.0, 530608.0, 211.0]),
#                                            ('id',
#                                             '967e6ef4fe4b36fc215f1e7300d3a4b2c2a0eada')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [261732.0, 541328.0, 211.0]),
#                                            ('id',
#                                             'a25034bc1d8540ff2ee68f8cb3a83648e7b702c7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [311230.0, 541784.0, 211.0]),
#                                            ('id',
#                                             '4be5998ec5833e56c124b46bd3eae3f0e2c3833d')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [834686.0, 184746.0, 211.0]),
#                                            ('id',
#                                             '523a2f339edbd2106ab0d344db0249dd373b3f22')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [221968.0, 489042.0, 211.0]),
#                                            ('id',
#                                             '66adc4ca3431b1ff4c7c01fcbbe00937b3391a93')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [595492.0, 190916.0, 211.0]),
#                                            ('id',
#                                             '475dc2a6e9b9946f66fa20a927cf1524a9073afe')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [559034.0, 461166.0, 211.0]),
#                                            ('id',
#                                             '66971c70fc7a3a407a4d268cbd6cd639b2afdfb3')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [380020.0, 386712.0, 211.0]),
#                                            ('id',
#                                             'f0b45267e9608bf11ed5ef0fad41dd1a5ddbb36f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [626044.0, 318658.0, 211.0]),
#                                            ('id',
#                                             '635d5e28fd99791442e19f0341f48fb6c38c2baa')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [534196.0, 179386.0, 211.0]),
#                                            ('id',
#                                             '9a22462e86909885a3dbad62782209552eeca728')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [511246.0, 218600.0, 211.0]),
#                                            ('id',
#                                             '329e5b9ee66bf0e083d0cc50228da5c42db82892')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [675492.0, 210884.0, 211.0]),
#                                            ('id',
#                                             '8444e01f67310a4c9190ccf6c2f6a483274bac0f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [670358.0, 457576.0, 211.0]),
#                                            ('id',
#                                             '6408390da979912bb7d2ede150c1a7cac9f1ceb8')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [491432.0, 407568.0, 211.0]),
#                                            ('id',
#                                             'b64c813362233b575a5d4586cd44d697d1055480')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [275270.0, 397708.0, 211.0]),
#                                            ('id',
#                                             '3027d68fe0fe338a9675bd660980f29546120ab8')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [215786.0, 398744.0, 211.0]),
#                                            ('id',
#                                             'a61dcc351e7bf66e4a3afa96cbc59ed64e843792')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [193864.0, 553272.0, 211.0]),
#                                            ('id',
#                                             '934b43d62815029b2c520b758dc82ae4dfd5129f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [803840.0, 205530.0, 211.0]),
#                                            ('id',
#                                             'f17757613ffbefcbf015117a21a482aa47eaa594')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [177518.0, 461210.0, 211.0]),
#                                            ('id',
#                                             '2919b3391029b509ed5e0507126b5143a1ce4209')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [159792.0, 502580.0, 211.0]),
#                                            ('id',
#                                             '5b288e6ddbe309c2716d6e6dfb834ac56a66e384')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [332586.0, 547236.0, 211.0]),
#                                            ('id',
#                                             '530da9601ad6826a68d6917f2052ed868d30ce27')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [172400.0, 488286.0, 211.0]),
#                                            ('id',
#                                             'cc527bb7bdd8609dace9c4bddc7466739c8d0637')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [154048.0, 471546.0, 211.0]),
#                                            ('id',
#                                             '80b74dc56e4ebb2819062b9487ccbce3a1b06377')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [157536.0, 456458.0, 211.0]),
#                                            ('id',
#                                             'c52598eafc55994db02bd3a82e778f45951caeaa')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [159848.0, 560158.0, 211.0]),
#                                            ('id',
#                                             '3a99ed9a87420ad4548a55b18fcd4ac940324c3f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [489384.0, 164582.0, 211.0]),
#                                            ('id',
#                                             '4617bb537abcced9a970dbbc2f76146ef9bbcb86')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [147440.0, 425724.0, 211.0]),
#                                            ('id',
#                                             'e2e0725437a9ee55fdd2d3369d181aa11784308c')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [547716.0, 189016.0, 211.0]),
#                                            ('id',
#                                             '085b333493206c120213a83874655096a13894b0')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [314812.0, 372152.0, 211.0]),
#                                            ('id',
#                                             '82e149edd4fc95df4891b8ece59e3e9a847d4997')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [334150.0, 334760.0, 211.0]),
#                                            ('id',
#                                             'ee6cc2f17c63daed96c75d3c45938e6bc3489069')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [593524.0, 343464.0, 211.0]),
#                                            ('id',
#                                             'b9d2ee95f308a3c628fdcb8912190dd19f1d76d2')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [682574.0, 250292.0, 211.0]),
#                                            ('id',
#                                             '08dd4bbbb618d7ccd02f06d63a071df8d8e05b7a')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [747284.0, 392980.0, 211.0]),
#                                            ('id',
#                                             'ffa070199c75f2a307c9c6431d4d0951b15698df')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [754850.0, 184160.0, 211.0]),
#                                            ('id',
#                                             '2128dbc0f03ae468ee11a99def392279ff86a5a0')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [314762.0, 444868.0, 211.0]),
#                                            ('id',
#                                             '3de1408ee2ecf542ca98f0b16c38e68e776f57c6')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [259912.0, 519330.0, 211.0]),
#                                            ('id',
#                                             '20fde9df2d2d2e104c90f9f241b091b5436d1023')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [292038.0, 368752.0, 211.0]),
# ...
#                                            ('point',
#                                             [350042.0, 439772.0, 211.0]),
#                                            ('id',
#                                             '4541f797340a2b60f3ee1b566fad42f9b64f1364')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [415470.0, 345086.0, 211.0]),
#                                            ('id',
#                                             'a2fcf444c90e0ed6e079c03f15030104fa23e290')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [446288.0, 492044.0, 211.0]),
#                                            ('id',
#                                             'ae73caca813aa7183d55ac9ebdbc2f319965eaa2')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [584906.0, 279246.0, 211.0]),
#                                            ('id',
#                                             '84e811ec686010c9e898073a76d0d5d6c1fa8f9b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [196096.0, 542782.0, 211.0]),
#                                            ('id',
#                                             'c7c87aa14a608233af43685b5a26b39a764fe147')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [530358.0, 317598.0, 211.0]),
#                                            ('id',
#                                             '05ab6af64b5551cce483dc08b350f1fbf95e209b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [640056.0, 197108.0, 211.0]),
#                                            ('id',
#                                             'bca420ef3940b86fa6475e77772e6c1d3688b739')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [404564.0, 542584.0, 211.0]),
#                                            ('id',
#                                             'a64d4dc041d4a0d98e286f906f3ebc940996238c')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [519690.0, 239580.0, 211.0]),
#                                            ('id',
#                                             'f86f6c45e04c1faedbe7295750aecd60a845b17c')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [732088.0, 235050.0, 211.0]),
#                                            ('id',
#                                             '9d155fde9019e1bac15aa2f2b432e55c965a8248')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [773210.0, 425832.0, 211.0]),
#                                            ('id',
#                                             '5a22d40419e51ed9036a2c751de7cd4e205b532b')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [676832.0, 319270.0, 211.0]),
#                                            ('id',
#                                             '4558e94b6bba3669c08ec6a44f649bdf320cb0f7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [676474.0, 159298.0, 211.0]),
#                                            ('id',
#                                             '6523a5e8dde66b219f0f6623f386201e96edb534')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [632480.0, 208866.0, 211.0]),
#                                            ('id',
#                                             '3ab632d1f13685f3692d6be01d1741a649a75f9e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [542290.0, 416926.0, 211.0]),
#                                            ('id',
#                                             '19b64d92497bc4769c48cb575945c7b4bca4ea84')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [803198.0, 387212.0, 211.0]),
#                                            ('id',
#                                             '98f11a83ebba00bc1c9b376f7b696e83081353ba')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [645232.0, 490378.0, 211.0]),
#                                            ('id',
#                                             'd8906d2bfb7e24639c180e3eb31aee108322e8f9')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [843370.0, 429474.0, 211.0]),
#                                            ('id',
#                                             '814590699720cd609b767f88a3f4dc76e47f2a68')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [684042.0, 257514.0, 211.0]),
#                                            ('id',
#                                             '69d17db527c2c7c72b51479e4f8c216d94422871')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [836862.0, 186672.0, 211.0]),
#                                            ('id',
#                                             'f64b17303ad5fe5fa8efabcf2d66a0021c3d5089')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [455168.0, 299330.0, 211.0]),
#                                            ('id',
#                                             'b98f7e81f03d76dd458aa2cba54117f138319afd')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [206398.0, 535592.0, 211.0]),
#                                            ('id',
#                                             '92155ef6fc183c8bc280364a0525bc28cea02af8')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [624318.0, 393514.0, 211.0]),
#                                            ('id',
#                                             '7c99ab459e65f57c356c02cf0fa99128ff6dff6f')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [673504.0, 489800.0, 211.0]),
#                                            ('id',
#                                             '0cd9d072ece5072a3d1a3aa37bebb6b1c9000707')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [851258.0, 247980.0, 211.0]),
#                                            ('id',
#                                             '44524548e25f7ee3f2d2b5d475d1899d8bb6a0e7')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [632172.0, 136272.0, 211.0]),
#                                            ('id',
#                                             '1f70826345aff35feefc9bbc299b2d7f7a982648')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [602700.0, 473896.0, 211.0]),
#                                            ('id',
#                                             '59b9fa5fcf8ffcb0c2f88af17cf417b3942a5920')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [574360.0, 414636.0, 211.0]),
#                                            ('id',
#                                             '31cef1f8fa16b5fd1a55c50fc0b4b4280e3fa2ce')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [690864.0, 242206.0, 211.0]),
#                                            ('id',
#                                             '6dc6d2683f441b4a19ca24034be4f802959b7bfa')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [618676.0, 364960.0, 211.0]),
#                                            ('id',
#                                             '46fc437016612aedf9af4f4140cb4248661030b5')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [339818.0, 377592.0, 211.0]),
#                                            ('id',
#                                             '589f7da72b6fbb26cdb0d957dfa8f9fe88642813')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [612094.0, 304198.0, 211.0]),
#                                            ('id',
#                                             'd54a60bb21d68d5f281eb2e4844bc807d325a392')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [719986.0, 358424.0, 211.0]),
#                                            ('id',
#                                             '3576725a5c0fb29c79f0469a4be5cf6b6c430a32')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [436546.0, 364384.0, 211.0]),
#                                            ('id',
#                                             '16c27e0d8060b25380bb53232f152d9cc7e606dc')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [810722.0, 447596.0, 211.0]),
#                                            ('id',
#                                             'ebef9f9d673ad83fe1658dad85f2d7f84ccee4ac')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [793892.0, 324438.0, 211.0]),
#                                            ('id',
#                                             '4baf329a67a8147b5c8875ec92492a441a9e2e87')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [510222.0, 290090.0, 211.0]),
#                                            ('id',
#                                             '274af2e452b289096f89b5aa67f5722f0ae1ce10')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [705754.0, 205006.0, 211.0]),
#                                            ('id',
#                                             '2ce95e46722fc7ed0041dc0371b9548ebd9936a6')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [394430.0, 333232.0, 211.0]),
#                                            ('id',
#                                             'a1db5d7b1c725922b62ddbfe84d9407063fce333')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [198782.0, 524642.0, 211.0]),
#                                            ('id',
#                                             'ca7ac3bd80aa80ff7c2113b63b1cdd89009d4fcf')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [696348.0, 383440.0, 211.0]),
#                                            ('id',
#                                             'b05151ddef100d211432cd8b42a31ef249ed1225')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [935380.0, 376794.0, 211.0]),
#                                            ('id',
#                                             '491c7918aa8c44c6ea1dfd1810f55a19a9e7d90e')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [899554.0, 311144.0, 211.0]),
#                                            ('id',
#                                             '14cb0ecff1b375b75a4991ba5a99911b7f5752ae')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [476184.0, 243512.0, 211.0]),
#                                            ('id',
#                                             'a3d265abb6a2157d6a7cec93b849886a5d891edb')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [816472.0, 438918.0, 211.0]),
#                                            ('id',
#                                             'b3d621538e9c9e660984ea3b94c3c4c1a46432cd')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [925266.0, 371184.0, 211.0]),
#                                            ('id',
#                                             '12f70f8a1e0a739df5f68f87cfe7c2da13c68fa4')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [920558.0, 295912.0, 211.0]),
#                                            ('id',
#                                             '018a01bca367d855bf6103af075b5c08560907de')]),
#                               OrderedDict([('type', 'point'),
#                                            ('point',
#                                             [694540.0, 181832.0, 211.0]),
#                                            ('id',
#                                             'f7e9b6f7c45f15f55574d06bae7b2aeccc446d2d')])]),
#                             ('name', 'annos')])]),
#              ('dimensions', OrderedDict()),
#              ('position', [447592.0, 376708.0, 211.1999969482422])])

# %%
state_id=client.state.upload_state_json(d)

# %%
url=client.state.build_neuroglancer_url(state_id, 
                                        ngl_url = 'http://ngl.cave-explorer.org/').replace("/?json_url=", "#!middleauth+")

# %%
url
# Out:
# 'http://ngl.cave-explorer.org#!middleauth+https://global.brain-wire-test.org//nglstate/api/v1/5165354674290688'
